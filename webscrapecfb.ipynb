# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
#url: https://www.sports-reference.com/cfb/schools/duke/2019-schedule.html
##div_schedule , .left , .right , .center

# %%
page = requests.get("https://www.sports-reference.com/cfb/schools/duke/2019-schedule.html")
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.find(id = 'div_schedule'))
table = soup.find(id = 'div_schedule')
# Out:
# <div class="overthrow table_container" id="div_schedule">
# <table class="sortable stats_table" data-cols-to-freeze="2" id="schedule"><caption>12 Games Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
# <tr>
# <th aria-label="Games" class="poptip sort_default_asc center" data-stat="g" data-tip="Games" scope="col">G</th>
# <th aria-label="Date" class="poptip sort_default_asc center" data-stat="date_game" scope="col">Date</th>
# <th aria-label="Time" class="poptip center" data-stat="time_game" data-tip="Game time (all times Eastern)" scope="col">Time</th>
# <th aria-label="Day" class="poptip sort_default_asc center" data-stat="day_name" scope="col">Day</th>
# <th aria-label="School Name" class="poptip sort_default_asc center" data-stat="school_name" data-tip="School Name" scope="col">School</th>
# <th aria-label="game_location" class="poptip center" data-stat="game_location" scope="col"></th>
# <th aria-label="Opponent" class="poptip sort_default_asc center" data-stat="opp_name" scope="col">Opponent</th>
# <th aria-label="Conf" class="poptip sort_default_asc center" data-stat="conf_abbr" scope="col">Conf</th>
# <th aria-label="game_result" class="poptip center" data-stat="game_result" scope="col"></th>
# <th aria-label="Points" class="poptip center" data-stat="points" data-tip="Points" scope="col">Pts</th>
# <th aria-label="Opponent Points" class="poptip sort_default_asc center" data-stat="opp_points" data-tip="Opponent Points" scope="col">Opp</th>
# <th aria-label="Wins" class="poptip center" data-stat="wins" data-tip="Wins" scope="col">W</th>
# <th aria-label="Losses" class="poptip center" data-stat="losses" data-tip="Losses" scope="col">L</th>
# <th aria-label="Streak" class="poptip center" data-stat="game_streak" scope="col">Streak</th>
# <th aria-label="Notes" class="poptip sort_default_asc center" data-stat="notes" scope="col">Notes</th>
# </tr>
# </thead>
# <tbody>
# <tr><th class="right" data-stat="g" scope="row">1</th><td class="left" csk="2019-08-31" data-stat="date_game"><a href="/cfb/boxscores/2019-08-31-duke.html">Aug 31, 2019</a></td><td class="center" data-stat="time_game">12:00 PM</td><td class="left" csk="7" data-stat="day_name">Sat</td><td class="left" data-stat="school_name"><a href="/cfb/schools/duke/2019.html">Duke</a></td><td class="left" data-stat="game_location">N</td><td class="left" data-stat="opp_name">(2) <a href="/cfb/schools/alabama/2019.html">Alabama</a></td><td class="left" data-stat="conf_abbr"><a href="/cfb/conferences/sec/2019.html">SEC</a></td><td class="left" data-stat="game_result">L</td><td class="right" data-stat="points">3</td><td class="right" data-stat="opp_points">42</td><td class="right iz" data-stat="wins">0</td><td class="right" data-stat="losses">1</td><td class="left" csk="-1" data-stat="game_streak">L 1</td><td class="left iz" csk="ZZZ" data-stat="notes"></td></tr>
# <tr><th class="right" data-stat="g" scope="row">2</th><td class="left" csk="2019-09-07" data-stat="date_game"><a href="/cfb/boxscores/2019-09-07-duke.html">Sep 7, 2019</a></td><td class="center" data-stat="time_game">6:00 PM</td><td class="left" csk="7" data-stat="day_name">Sat</td><td class="left" data-stat="school_name"><a href="/cfb/schools/duke/2019.html">Duke</a></td><td class="left iz" data-stat="game_location"></td><td class="left" data-stat="opp_name">North Carolina A&amp;T</td><td class="left" data-stat="conf_abbr">Non-Major</td><td class="left" data-stat="game_result">W</td><td class="right" data-stat="points">45</td><td class="right" data-stat="opp_points">13</td><td class="right" data-stat="wins">1</td><td class="right" data-stat="losses">1</td><td class="left" csk="1" data-stat="game_streak">W 1</td><td class="left iz" csk="ZZZ" data-stat="notes"></td></tr>
# <tr><th class="right" data-stat="g" scope="row">3</th><td class="left" csk="2019-09-14" data-stat="date_game"><a href="/cfb/boxscores/2019-09-14-middle-tennessee-state.html">Sep 14, 2019</a></td><td class="center" data-stat="time_game">7:00 PM</td><td class="left" csk="7" data-stat="day_name">Sat</td><td class="left" data-stat="school_name"><a href="/cfb/schools/duke/2019.html">Duke</a></td><td class="left" data-stat="game_location">@</td><td class="left" data-stat="opp_name"><a href="/cfb/schools/middle-tennessee-state/2019.html">Middle Tennessee State</a></td><td class="left" data-stat="conf_abbr"><a href="/cfb/conferences
><td class="left iz" csk="ZZZ" data-stat="notes"></td></tr>
# <tr><th class="right" data-stat="g" scope="row">10</th><td class="left" csk="2019-11-16" data-stat="date_game"><a href="/cfb/boxscores/2019-11-16-duke.html">Nov 16, 2019</a></td><td class="center" data-stat="time_game">12:00 PM</td><td class="left" csk="7" data-stat="day_name">Sat</td><td class="left" data-stat="school_name"><a href="/cfb/schools/duke/2019.html">Duke</a></td><td class="left iz" data-stat="game_location"></td><td class="left" data-stat="opp_name"><a href="/cfb/schools/syracuse/2019.html">Syracuse</a></td><td class="left" data-stat="conf_abbr"><a href="/cfb/conferences/acc/2019.html">ACC</a></td><td class="left iz" data-stat="game_result"></td><td class="right iz" data-stat="points"></td><td class="right iz" data-stat="opp_points"></td><td class="right iz" data-stat="wins"></td><td class="right iz" data-stat="losses"></td><td class="left iz" data-stat="game_streak"></td><td class="left iz" csk="ZZZ" data-stat="notes"></td></tr>
# <tr><th class="right" data-stat="g" scope="row">11</th><td class="left" csk="2019-11-23" data-stat="date_game"><a href="/cfb/boxscores/2019-11-23-wake-forest.html">Nov 23, 2019</a></td><td class="center" data-stat="time_game">12:00 PM</td><td class="left" csk="7" data-stat="day_name">Sat</td><td class="left" data-stat="school_name"><a href="/cfb/schools/duke/2019.html">Duke</a></td><td class="left" data-stat="game_location">@</td><td class="left" data-stat="opp_name">(23) <a href="/cfb/schools/wake-forest/2019.html">Wake Forest</a></td><td class="left" data-stat="conf_abbr"><a href="/cfb/conferences/acc/2019.html">ACC</a></td><td class="left iz" data-stat="game_result"></td><td class="right iz" data-stat="points"></td><td class="right iz" data-stat="opp_points"></td><td class="right iz" data-stat="wins"></td><td class="right iz" data-stat="losses"></td><td class="left iz" data-stat="game_streak"></td><td class="left iz" csk="ZZZ" data-stat="notes"></td></tr>
# <tr><th class="right" data-stat="g" scope="row">12</th><td class="left" csk="2019-11-30" data-stat="date_game"><a href="/cfb/boxscores/2019-11-30-duke.html">Nov 30, 2019</a></td><td class="center" data-stat="time_game">12:00 PM</td><td class="left" csk="7" data-stat="day_name">Sat</td><td class="left" data-stat="school_name"><a href="/cfb/schools/duke/2019.html">Duke</a></td><td class="left iz" data-stat="game_location"></td><td class="left" data-stat="opp_name"><a href="/cfb/schools/miami-fl/2019.html">Miami (FL)</a></td><td class="left" data-stat="conf_abbr"><a href="/cfb/conferences/acc/2019.html">ACC</a></td><td class="left iz" data-stat="game_result"></td><td class="right iz" data-stat="points"></td><td class="right iz" data-stat="opp_points"></td><td class="right iz" data-stat="wins"></td><td class="right iz" data-stat="losses"></td><td class="left iz" data-stat="game_streak"></td><td class="left iz" csk="ZZZ" data-stat="notes"></td></tr>
# </tbody></table>
# </div>

# %%
thead = table.find('thead')
th_head = thead.find_all('th')
th_head
# Out:
# [<th aria-label="Games" class="poptip sort_default_asc center" data-stat="g" data-tip="Games" scope="col">G</th>,
#  <th aria-label="Date" class="poptip sort_default_asc center" data-stat="date_game" scope="col">Date</th>,
#  <th aria-label="Time" class="poptip center" data-stat="time_game" data-tip="Game time (all times Eastern)" scope="col">Time</th>,
#  <th aria-label="Day" class="poptip sort_default_asc center" data-stat="day_name" scope="col">Day</th>,
#  <th aria-label="School Name" class="poptip sort_default_asc center" data-stat="school_name" data-tip="School Name" scope="col">School</th>,
#  <th aria-label="game_location" class="poptip center" data-stat="game_location" scope="col"></th>,
#  <th aria-label="Opponent" class="poptip sort_default_asc center" data-stat="opp_name" scope="col">Opponent</th>,
#  <th aria-label="Conf" class="poptip sort_default_asc center" data-stat="conf_abbr" scope="col">Conf</th>,
#  <th aria-label="game_result" class="poptip center" data-stat="game_result" scope="col"></th>,
#  <th aria-label="Points" class="poptip center" data-stat="points" data-tip="Points" scope="col">Pts</th>,
#  <th aria-label="Opponent Points" class="poptip sort_default_asc center" data-stat="opp_points" data-tip="Opponent Points" scope="col">Opp</th>,
#  <th aria-label="Wins" class="poptip center" data-stat="wins" data-tip="Wins" scope="col">W</th>,
#  <th aria-label="Losses" class="poptip center" data-stat="losses" data-tip="Losses" scope="col">L</th>,
#  <th aria-label="Streak" class="poptip center" data-stat="game_streak" scope="col">Streak</th>,
#  <th aria-label="Notes" class="poptip sort_default_asc center" data-stat="notes" scope="col">Notes</th>]

# %%
names = []
for thh in th_head:
   names.append(thh.get('data-stat'))
names
# Out:
# ['g',
#  'date_game',
#  'time_game',
#  'day_name',
#  'school_name',
#  'game_location',
#  'opp_name',
#  'conf_abbr',
#  'game_result',
#  'points',
#  'opp_points',
#  'wins',
#  'losses',
#  'game_streak',
#  'notes']

# %%
tbody = table.find('tbody')
tr_body = tbody.find_all('tr')
tr_body

a = []
for trb in tr_body:
    d = []
    th = trb.find('th')
    x = (th.get_text())
    d.append(x)
    a.append(d)
    
    for td in trb.find_all('td'):
        y = (td.get_text())
        d.append(y)
    

df = pd.DataFrame(a, columns =names)
df
# Out:
#      g     date_game time_game day_name school_name game_location  \
# 0    1  Aug 31, 2019  12:00 PM      Sat        Duke             N
# 1    2   Sep 7, 2019   6:00 PM      Sat        Duke
# 2    3  Sep 14, 2019   7:00 PM      Sat        Duke             @
# 3    4  Sep 27, 2019   7:00 PM      Fri        Duke             @
# 4    5   Oct 5, 2019   8:00 PM      Sat        Duke
# 5    6  Oct 12, 2019  12:30 PM      Sat        Duke
# 6    7  Oct 19, 2019   3:30 PM      Sat        Duke             @
# 7    8  Oct 26, 2019   4:00 PM      Sat        Duke             @
# 8    9   Nov 9, 2019   7:30 PM      Sat        Duke
# 9   10  Nov 16, 2019  12:00 PM      Sat        Duke
# 10  11  Nov 23, 2019  12:00 PM      Sat        Duke             @
# 11  12  Nov 30, 2019  12:00 PM      Sat        Duke
#
#                   opp_name  conf_abbr game_result points opp_points wins  \
# 0              (2) Alabama        SEC           L      3         42    0
# 1       North Carolina A&T  Non-Major           W     45         13    1
# 2   Middle Tennessee State       CUSA           W     41         18    2
# 3            Virginia Tech        ACC           W     45         10    3
# 4                     Pitt        ACC           L     30         33    3
# 5             Georgia Tech        ACC           W     41         23    4
# 6                 Virginia        ACC           L     14         48    4
# 7           North Carolina        ACC           L     17         20    4
# 8          (16) Notre Dame        Ind
# 9                 Syracuse        ACC
# 10        (23) Wake Forest        ACC
# 11              Miami (FL)        ACC
#
#    losses game_streak notes
# 0       1         L 1
# 1       1         W 1
# 2       1         W 2
# 3       1         W 3
# 4       2         L 1
# 5       2         W 1
# 6       3         L 1
# 7       4         L 2
# 8
# 9
# 10
# 11

# %%
#https://www.sports-reference.com/cfb/schools/clemson/2019-schedule.html
teams = ['duke', 'clemson']
b = []
for names in range(len(teams)):
    page = requests.get("https://www.sports-reference.com/cfb/schools/" + teams[names] + "/2019-schedule.html")
    soup = BeautifulSoup(page.content, 'html.parser')
    table = soup.find(id = 'div_schedule')
    tbody = table.find('tbody')
    tr_body = tbody.find_all('tr')
    tr_body

    for trb in tr_body:
        d = []
        th = trb.find('th')
        x = (th.get_text())
        d.append(x)
        b.append(d)
    
        for td in trb.find_all('td'):
            y = (td.get_text())
            d.append(y)
    

please_work = pd.DataFrame(b)
please_work
# Out:
#     0             1         2    3            4  5                       6   \
# 0    1  Aug 31, 2019  12:00 PM  Sat         Duke  N             (2) Alabama
# 1    2   Sep 7, 2019   6:00 PM  Sat         Duke         North Carolina A&T
# 2    3  Sep 14, 2019   7:00 PM  Sat         Duke  @  Middle Tennessee State
# 3    4  Sep 27, 2019   7:00 PM  Fri         Duke  @           Virginia Tech
# 4    5   Oct 5, 2019   8:00 PM  Sat         Duke                       Pitt
# 5    6  Oct 12, 2019  12:30 PM  Sat         Duke               Georgia Tech
# 6    7  Oct 19, 2019   3:30 PM  Sat         Duke  @                Virginia
# 7    8  Oct 26, 2019   4:00 PM  Sat         Duke  @          North Carolina
# 8    9   Nov 9, 2019   7:30 PM  Sat         Duke            (16) Notre Dame
# 9   10  Nov 16, 2019  12:00 PM  Sat         Duke                   Syracuse
# 10  11  Nov 23, 2019  12:00 PM  Sat         Duke  @        (23) Wake Forest
# 11  12  Nov 30, 2019  12:00 PM  Sat         Duke                 Miami (FL)
# 12   1  Aug 29, 2019   8:00 PM  Thu  (1) Clemson               Georgia Tech
# 13   2   Sep 7, 2019   3:30 PM  Sat  (1) Clemson             (12) Texas A&M
# 14   3  Sep 14, 2019   7:30 PM  Sat  (1) Clemson  @                Syracuse
# 15   4  Sep 21, 2019   7:30 PM  Sat  (1) Clemson                  Charlotte
# 16   5  Sep 28, 2019   3:30 PM  Sat  (1) Clemson  @          North Carolina
# 17   6  Oct 12, 2019   3:30 PM  Sat  (2) Clemson              Florida State
# 18   7  Oct 19, 2019  12:00 PM  Sat  (3) Clemson  @              Louisville
# 19   8  Oct 26, 2019   7:30 PM  Sat  (4) Clemson             Boston College
# 20   9   Nov 2, 2019   4:00 PM  Sat  (4) Clemson                    Wofford
# 21  10   Nov 9, 2019   7:30 PM  Sat  (4) Clemson  @    North Carolina State
# 22  11  Nov 16, 2019  12:00 PM  Sat  (4) Clemson           (23) Wake Forest
# 23  12  Nov 30, 2019  12:00 PM  Sat  (4) Clemson  @          South Carolina
#
#            7  8   9   10 11 12   13 14
# 0         SEC  L   3  42  0  1  L 1
# 1   Non-Major  W  45  13  1  1  W 1
# 2        CUSA  W  41  18  2  1  W 2
# 3         ACC  W  45  10  3  1  W 3
# 4         ACC  L  30  33  3  2  L 1
# 5         ACC  W  41  23  4  2  W 1
# 6         ACC  L  14  48  4  3  L 1
# 7         ACC  L  17  20  4  4  L 2
# 8         Ind
# 9         ACC
# 10        ACC
# 11        ACC
# 12        ACC  W  52  14  1  0  W 1
# 13        SEC  W  24  10  2  0  W 2
# 14        ACC  W  41   6  3  0  W 3
# 15       CUSA  W  52  10  4  0  W 4
# 16        ACC  W  21  20  5  0  W 5
# 17        ACC  W  45  14  6  0  W 6
# 18        ACC  W  45  10  7  0  W 7
# 19        ACC  W  59   7  8  0  W 8
# 20  Non-Major  W  59  14  9  0  W 9
# 21        ACC
# 22        ACC
# 23        SEC
